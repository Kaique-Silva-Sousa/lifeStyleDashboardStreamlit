# %%
import pandas as pd

# %%
df = pd.read_csv('./data/Final_data.csv')

# %%
pd.options.display.max_columns = None

# %%
df.head(1)
# Out:
#      Age Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0  34.91   Male        65.27        1.62   188.58   157.65        69.05
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                       1.0           1080.9     Strength       26.800377
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    1.5                           3.99              2.01
#
#      BMI  Daily meals frequency  Physical exercise   Carbs  Proteins   Fats  \
# 0  24.87                   2.99               0.01  267.68    106.05  71.63
#
#    Calories meal_name meal_type diet_type  sugar_g  sodium_mg  cholesterol_mg  \
# 0    1806.0     Other     Lunch     Vegan    31.77    1729.94          285.05
#
#    serving_size_g cooking_method  prep_time_min  cook_time_min  rating  \
# 0          120.47        Grilled          16.24         110.79    1.31
#
# ...

# %%
df.groupby('meal_type')['Calories'].mean().reset_index()
# Out:
#    meal_type     Calories
# 0  Breakfast  2015.484240
# 1     Dinner  2030.272002
# 2      Lunch  2021.396275
# 3      Snack  2030.550091
